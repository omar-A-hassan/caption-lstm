# %%
# !git clone https://github.com/omar-A-hassan/caption-lstm
# Out:
# Cloning into 'caption-lstm'...
# remote: Enumerating objects: 953, done.
# remote: Counting objects: 100% (182/182), done.
# remote: Compressing objects: 100% (57/57), done.
# remote: Total 953 (delta 143), reused 146 (delta 125), pack-reused 771 (from 1)
# Receiving objects: 100% (953/953), 1.64 MiB | 29.02 MiB/s, done.
# Resolving deltas: 100% (419/419), done.

# %%
# %cd caption-lstm
# Out:
# /kaggle/working/caption-lstm

# %%
# !ls -R
# Out:
# .:
# caption_lstm  eval.py	  LICENSE_APACHE  logs	     src	vision_lstm
# docs	      hubconf.py  LICENSE_MIT	  README.md  tutorials
#
# ./caption_lstm:
# decoder.py  fusion.py  __init__.py  mbr_decoder.py  model.py  tokenizer.py
#
# ./docs:
# _config.yml  imgs  index.md
#
# ./docs/imgs:
# flops_vs_performance.png  results_imagenet.png	  schematic.svg
# results_ade20k.png	  results_tiny_small.png
# results_base.png	  results_vtab1k.png
#
# ./logs:
# clean_logs.py  pretrain
#
# ./logs/pretrain:
# vil_b16_e400_finetune.log	vil_t16_e400_finetune.log
# vil_b16_e400_pretrain_run1.log	vil_t16_e400_pretrain.log
# vil_b16_e400_pretrain_run2.log	vil_t16_e800_finetune.log
# vil_s16_e400_finetune.log	vil_t16_e800_pretrain_run1.log
# vil_s16_e400_pretrain.log	vil_t16_e800_pretrain_run2.log
#
# ./src:
# environment.yml  main_run_folder.py  main_train.py  setup     vislstm
# ksuit		 main_sbatch.py      RUN.md	    SETUP.md
#
# ./src/ksuit:
# callbacks  datasets	freezers      losses   optim		 runners
# configs    distributed	initializers  metrics  pattern_matchers  trainers
# data	   factory	__init__.py   models   providers	 utils
#
# ./src/ksuit/callbacks:
# base		      __init__.py	 online_callbacks
# checkpoint_callbacks  monitor_callbacks  visualization_callbacks
# default_callbacks     offline_callbacks
#
# ./src/ksuit/callbacks/base:
# callback_base.py  __init__.py  periodic_callback.py  writers
#
# ./src/ksuit/callbacks/base/writers:
# checkpoint_writer.py  __init__.py  log_writer.py
#
# ./src/ksuit/callbacks/checkpoint_callbacks:
# best_checkpoint_callback.py  ema_callback.py
# checkpoint_callback.py	     __init__.py
#
# ./src/ksuit/callbacks/default_callbacks:
# copy_previous_config_callback.py   lr_callback.py
# copy_previous_summary_callback.py  online_loss_callback.py
# dataset_stats_callback.py	   param_count_callback.py
# eta_callback.py			   peak_memory_callback.py
# freezer_callback.py		   progress_callback.py
# __init__.py			   train_time_callback.py
#
# ./src/ksuit/callbacks/monitor_callbacks:
# activation_monitor_callback.py	    nan_hook_monitor_callback.py
# debug_monitor_callback.py	    nan_loss_monitor_callback.py
# gradient_monitor_callback.py	    skip_loss_spikes_callback.py
# gradient_spike_monitor_callback.py  skip_nan_loss_callback.py
# __init__.py			    weight_monitor_callback.py
# kill_on_loss_spike_callback.py
#
# ./src/ksuit/callbacks/offline_callbacks:
# __init__.py		      offline_loss_callback.py
# offline_accuracy_callback.py  offline_multiclass_knn_callback.py
# offline_features_callback.py  offline_segmentation_callback.py
#
# ./src/ksuit/callbacks/online_callbacks:
# __init__.py		     online_segmentation_callback.py
# online_accuracy_callback.py  update_output_callback.py
#
# ./src/ksuit/callbacks/visualization_callbacks:
# __init__.py  visualize_segmentation_callback.py
#
# ./src/ksuit/configs:
# cli_args.py	__init__.py	     static_config.py
# hyperparams.py	resolver_processors  wandb_config.py
#
# ./src/ksuit/configs/resolver_processors:
# __init__.py		      precision_preprocessor.py
# mindata_postprocessor.py      remove_large_collections_postprocessor.py
# minduration_postprocessor.py  schedule_template_postprocessor.py
# minmodel_postprocessor.py     testrun_postprocessor.py
# minmodel_preprocessor.py
#
# ./src/ksuit/data:
# base	   copy      error_messages.py	__init__.py  transforms  wrappers
# collators  download  errors.py		loaders      utils
#
# ./src/ksuit/data/base:
# dataset.py  __init__.py  subset.py  wrapper.py
#
# ./src/ksuit/data/collators:
# caption_collator.py  compose_collator.py  stochastic_collator.py
# collator.py	     __init__.py
#
# ./src/ksuit/data/copy:
# __init__.py  multiclass_dataset.py  utils.py
#
# ./src/ksuit/data/download:
# cifar100.py  cifar10.py  __init__.py  vtab1k.py
#
# ./src/ksuit/data/loaders:
# __init__.py
#
# ./src/ksuit/data/transforms:
# base  __init__.py  norm
#
# ./src/ksuit/data/transforms/base:
# compose_transform.py  __init__.py  stochastic_transform.py  transform.py
#
# ./src/ksuit/data/transforms/norm:
# base  image_moment_norm.py  image_range_norm.py  __init__.py
#
# ./src/ksuit/data/transforms/norm/base:
# __init__.py  norm_base.py
#
# ./src/ksuit/data/utils:
# __init__.py  optional_kwargs.py  random.py
#
# ./src/ksuit/data/wrappers:
# dataset_wrappers  __init__.py  mode_wrapper.py	sample_wrappers
#
# ./src/ksuit/data/wrappers/dataset_wrappers:
# class_subset_wrapper.py  repeat_wrapper.py   subset_wrapper.py
# __init__.py		 shuffle_wrapper.py
#
# ./src/ksuit/data/wrappers/sample_wrappers:
# base	     label_smoothing_wrapper.py  x_transform_wrapper.py
# __init__.py  one_hot_wrapper.py
#
# ./src/ksuit/data/wrappers/sample_wrappers/base:
# __init__.py  transform_wrapper_base.py
#
# ./src/ksuit/datasets:
# coco_captions_dataset.py  __init__.py  multiclass_dataset.py  random_dataset.py
#
# ./src/ksuit/distributed:
# config	functional  gather.py  __init__.py  run
#
# ./src/ksuit/distributed/config:
# base_config.py	default_config.py  __init__.py
#
# ./src/ksuit/distributed/functional:
# all_gather_grad_autograd.py  all_gather_grad_overwrite.py  __init__.py
#
# ./src/ksuit/distributed/run:
# __init__.py  managed.py  unmanaged.py  utils.py
#
# ./src/ksuit/factory:
# base		    __init__.py       optim_factory.py	   transform_factory.py
# dataset_factory.py  model_factory.py  schedule_factory.py
#
# ./src/ksuit/factory/base:
# empty_factory.py  __init__.py	     reflection.py
# factory_base.py   master_factory.py  single_factory.py
#
# ./src/ksuit/freezers:
# base  full_freezer.py  __init__.py  pattern_freezer.py
#
# ./src/ksuit/freezers/base:
# freezer_base.py  __init__.py
#
# ./src/ksuit/initializers:
# base				      resume_initializer.py
# __init__.py			      state_dict_initializer.py
# previous_run_initializer.py	      torchhub_initializer.py
# reset_classifier_head_initializer.py
#
# ./src/ksuit/initializers/base:
# checkpoint_initializer.py  initializer_base.py	__init__.py
#
# ./src/ksuit/losses:
# base  basic  elementwise_loss.py  __init__.py
#
# ./src/ksuit/losses/base:
# __init__.py  loss_base.py
#
# ./src/ksuit/losses/basic:
# __init__.py  l1_loss.py  mse_loss.py  smooth_l1_loss.py
#
# ./src/ksuit/metrics:
# __init__.py  multiclass_knn.py
#
# ./src/ksuit/models:
# base	    identity_model.py  linear_model.py	torchhub_model.py
# extractors  __init__.py        poolings		torchvision_model.py
#
# ./src/ksuit/models/base:
# composite_model.py  __init__.py  model_base.py	single_model.py
#
# ./src/ksuit/models/extractors:
# base  block_extractor.py  finalizers  __init__.py  single_extractor.py
#
# ./src/ksuit/models/extractors/base:
# extractor_base.py  __init__.py		      with_extractor_hooks.py
# forward_hook.py    stop_forward_exception.py  without_extractor_hooks.py
#
# ./src/ksuit/models/extractors/finalizers:
# concat_finalizer.py  __init__.py	stack_finalizer.py
# index_finalizer.py   mean_finalizer.py
#
# ./src/ksuit/models/poolings:
# all_patches.py	concat_class_average.py  __init__.py   mean_all.py
# base		identity.py		 max_all.py    mean_patch.py
# class_token.py	index_pooling.py	 max_patch.py  to_image.py
#
# ./src/ksuit/models/poolings/base:
# __init__.py  pooling_base.py
#
# ./src/ksuit/optim:
# __init__.py  lr_scalers  optim_wrapper.py  param_group_modifiers
#
# ./src/ksuit/optim/lr_scalers:
# __init__.py  linear_lr_scaler.py  lr_scaler_base.py  sqrt_lr_scaler.py
#
# ./src/ksuit/optim/param_group_modifiers:
# base	     lr_scale_by_name_modifier.py
# __init__.py  weight_decay_by_name_modifier.py
#
# ./src/ksuit/optim/param_group_modifiers/base:
# __init__.py  param_group_modifier_base.py
#
# ./src/ksuit/pattern_matchers:
# base  fnmatch_pattern_matcher.py  __init__.py  regex_pattern_matcher.py
#
# ./src/ksuit/pattern_matchers/base:
# __init__.py  pattern_matcher.py
#
# ./src/ksuit/providers:
# config_providers	    __init__.py			 path_provider.py
# dataset_config_provider.py  metric_property_provider.py  summary_providers
#
# ./src/ksuit/providers/config_providers:
# base	     noop_config_provider.py	   wandb_config_provider.py
# __init__.py  primitive_config_provider.py
#
# ./src/ksuit/providers/config_providers/base:
# config_provider_base.py  __init__.py
#
# ./src/ksuit/providers/summary_providers:
# base	     noop_summary_provider.py	    wandb_summary_provider.py
# __init__.py  primitive_summary_provider.py
#
# ./src/ksuit/providers/summary_providers/base:
# __init__.py  summary_provider_base.py
#
# ./src/ksuit/runners:
# __init__.py  runner.py
#
# ./src/ksuit/trainers:
# base			   early_stoppers  segmentation_trainer.py
# classification_trainer.py  __init__.py
#
# ./src/ksuit/trainers/base:
# __init__.py  sgd_trainer.py
#
# ./src/ksuit/trainers/early_stoppers:
# base  __init__.py  metric_early_stopper.py
#
# ./src/ksuit/trainers/early_stoppers/base:
# early_stopper_base.py  __init__.py
#
# ./src/ksuit/utils:
# amp_utils.py	     model_utils.py	      select_with_path.py
# bidict.py	     naming_utils.py	      system_info.py
# checkpoint.py	     noop_tqdm.py	      tensor_hashing.py
# data_container.py    num_worker_heuristic.py  transform_utils.py
# formatting_utils.py  one_hot_utils.py	      update_counter.py
# __init__.py	     param_checking.py	      version_check.py
# logging_utils.py     pytorch_cuda_timing.py   wandb_utils.py
# math_utils.py	     schedule_wrapper.py
# miou_utils.py	     seed.py
#
# ./src/setup:
# sbatch_configs	sbatch_templates  static_configs  wandb_configs
#
# ./src/setup/sbatch_configs:
# prod.yaml
#
# ./src/setup/sbatch_templates:
# prod_nodes.sh
#
# ./src/setup/static_configs:
# dev.yaml  prod.yaml
#
# ./src/setup/wandb_configs:
# official.yaml
#
# ./src/vislstm:
# callbacks  datasets  initializers  models   optim     sample_wrappers  yamls
# collators  external  __init__.py   modules  poolings  transforms
#
# ./src/vislstm/callbacks:
# __init__.py
# offline_classsubset_accuracy_callback.py
# offline_imagenet_corruption_callback.py
#
# ./src/vislstm/collators:
# __init__.py  mix_collator.py
#
# ./src/vislstm/datasets:
# ade20k.py    imagenet1k.py	      imagenet_rendition.py
# cifar100.py  imagenet_adversarial.py  imagenet_sketch.py
# cifar10.py   imagenet_corruption.py   __init__.py
#
# ./src/vislstm/external:
# __init__.py  models_mamba.py
#
# ./src/vislstm/initializers:
# deit3_pretrained_initializer.py  __init__.py
# deit_pretrained_initializer.py	 vim_pretrained_initializer.py
#
# ./src/vislstm/models:
# __init__.py  single  upernet
#
# ./src/vislstm/models/single:
# __init__.py  vislstm.py  vismamba.py  vit.py
#
# ./src/vislstm/models/upernet:
# __init__.py	      upernet_decoder.py  upernet_postprocessor.py
# upernet_auxiliary.py  upernet_model.py
#
# ./src/vislstm/modules:
# __init__.py  sequence_conv2d.py  xlstm
#
# ./src/vislstm/modules/xlstm:
# blocks	components  __init__.py  utils.py  xlstm_block.py  xlstm_block_stack.py
#
# ./src/vislstm/modules/xlstm/blocks:
# __init__.py  mlstm  slstm  xlstm_block.py
#
# ./src/vislstm/modules/xlstm/blocks/mlstm:
# backends.py  block.py  cell.py	__init__.py  layer.py
#
# ./src/vislstm/modules/xlstm/blocks/slstm:
# block.py  cell.py  __init__.py	layer.py
#
# ./src/vislstm/modules/xlstm/components:
# conv.py		__init__.py  linear_headwise.py  util.py
# feedforward.py	init.py      ln.py
#
# ./src/vislstm/optim:
# __init__.py  layerwise_lr_decay.py
#
# ./src/vislstm/poolings:
# bilateral.py  first_token.py  __init__.py  last_token.py  middle_tokens.py
#
# ./src/vislstm/sample_wrappers:
# __init__.py  segmentation_transform_wrapper.py
#
# ./src/vislstm/transforms:
# cifar100_norm.py	resize.py
# cifar10_norm.py		segmentation_pad.py
# color_jitter.py		segmentation_random_crop.py
# gaussian_blur_pil.py	segmentation_random_horizontal_flip.py
# imagenet1k_norm.py	segmentation_random_resize.py
# __init__.py		segmentation_resize.py
# rand_augment.py		three_augment.py
# random_resized_crop.py
#
# ./src/vislstm/yamls:
# benchmark  longseq  misc  pretrain  robustness	segmentation  vit
#
# ./src/vislstm/yamls/benchmark:
# blockdesign  vil_vs_vim
#
# ./src/vislstm/yamls/benchmark/blockdesign:
# lstm_6M16_bidir_compile.yaml  lstm_6M16_nocompile.yaml
# lstm_6M16_compile.yaml	      lstm_6M16_qdir_nocompile.yaml
#
# ./src/vislstm/yamls/benchmark/vil_vs_vim:
# lstm_24m.yaml	lstm_6m.yaml   vim_26m.yaml   vim_7m.yaml
# lstm_300m.yaml	lstm_88m.yaml  vim_300m.yaml  vim_88m.yaml
#
# ./src/vislstm/yamls/longseq:
# vil.yaml  vit
#
# ./src/vislstm/yamls/longseq/vit:
# 42degt9q.yaml	 deit3_large.yaml  deit_base.yaml   hrngni5a.yaml
# deit3_base.yaml  deit3_small.yaml  deit_small.yaml
#
# ./src/vislstm/yamls/misc:
# finetune_from_torchhub.yaml
#
# ./src/vislstm/yamls/pretrain:
# vil  vit
#
# ./src/vislstm/yamls/pretrain/vil:
# 22M_res224finetuning.yaml
# 6M_res224finetuning.yaml
# 80M_res224finetuning_e5.yaml
# lstm_22M16_e400_bialter_bilatflat_conv2d3_lr1e3_res192_bias.yaml
# lstm_6M16_e400_bialter_bilatflat_conv2d3_lr1e3_res192_bias.yaml
# lstm_6M16_e800_bialter_bilatflat_conv2d3_lr1e3_res192_bias.yaml
# lstm_80M16_e400_bialter_bilatflat_conv2d3_lr1e3_res192_bias.yaml
# v1
#
# ./src/vislstm/yamls/pretrain/vil/v1:
# in100  pretrain
#
# ./src/vislstm/yamls/pretrain/vil/v1/in100:
# lstm_6M16_e400res128_bialter_bilatavg.yaml
# lstm_6M16_e400res128_bidir_bilatavg.yaml
# lstm_6M16_e400res128_bidirshare_bilatavg.yaml
# lstm_6M16_e400res128_qalter_bilatavg.yaml
# lstm_6M16_e400res128_qdir_bilatavg.yaml
# lstm_6M16_e400res128_qdirshare_bilatavg.yaml
# lstm_6M16_e400res128_unilast.yaml
#
# ./src/vislstm/yamls/pretrain/vil/v1/pretrain:
# lstm_24M16_e400_bialter_bilatavg_lr1e3_sd005unif_res224.yaml
# lstm_26M16_e400_bialter_bilatavg_lr1e3_sd005unif_res224.yaml
# lstm_6M16_e400_bialter_bilatavg_lr1e3_res224.yaml
# lstm_6M16_e800_bialter_bilatavg_lr1e3_res224.yaml
# lstm_7M16_e400_bialter_bilatavg_lr1e3_res224.yaml
# lstm_7M16_e800_bialter_bilatavg_lr1e3_res224.yaml
# lstm_90M16_e400_bialter_bilatavg_lr1e3_sd02unif_res224.yaml
# pooling
#
# ./src/vislstm/yamls/pretrain/vil/v1/pretrain/pooling:
# bialter_avg.yaml	bialter_bilatpatch.yaml  bialter_midpatch.yaml
# bialter_bilatflat.yaml	bialter_midcls.yaml	 finetune
#
# ./src/vislstm/yamls/pretrain/vil/v1/pretrain/pooling/finetune:
# example.yaml
#
# ./src/vislstm/yamls/pretrain/vit:
# deit3_tiny_e400_lr1e3.yaml  eval_imagenet1k
# deit3_tiny_e800_lr1e3.yaml  finetune.yaml
#
# ./src/vislstm/yamls/pretrain/vit/eval_imagenet1k:
# deit3_pretrained_small.yaml  deit_pretrained_small.yaml
#
# ./src/vislstm/yamls/robustness:
# vil  vim  vit
#
# ./src/vislstm/yamls/robustness/vil:
# vil2_b16.yaml  vil2_s16.yaml  vil2_t16.yaml
#
# ./src/vislstm/yamls/robustness/vim:
# vim_s16.yaml  vim_t16.yaml
#
# ./src/vislstm/yamls/robustness/vit:
# deit3_b16.yaml	deit3_t16.yaml	deit_s16.yaml
# deit3_s16.yaml	deit_b16.yaml	deit_t16.yaml
#
# ./src/vislstm/yamls/segmentation:
# deit3_b16_upernet160k_relpos_dim384.yaml  eval
# deit3_s16_upernet160k_relpos_dim384.yaml  vil_b16_upernet160k_dim384.yaml
# deit3_t16_upernet160k_relpos_dim192.yaml  vil_s16_upernet160k_dim384.yaml
# deit_b16_upernet160k_relpos_dim384.yaml   vil_t16_upernet160k_dim192_e400.yaml
# deit_s16_upernet160k_relpos_dim384.yaml   vil_t16_upernet160k_dim192.yaml
# deit_t16_upernet160k_relpos_dim192.yaml
#
# ./src/vislstm/yamls/segmentation/eval:
# example_vil_multiscale.yaml  example_vit_multiscale.yaml
# example_vil.yaml	     example_vit.yaml
#
# ./src/vislstm/yamls/vit:
# deit3_tiny_e400_lr1e3.yaml  eval	   longseq
# deit3_tiny_e800_lr1e3.yaml  finetune.yaml
#
# ./src/vislstm/yamls/vit/eval:
# deit3_pretrained_small.yaml  deit_pretrained_small.yaml
#
# ./src/vislstm/yamls/vit/longseq:
# 42degt9q.yaml	 deit3_large.yaml  deit_base.yaml   hrngni5a.yaml
# deit3_base.yaml  deit3_small.yaml  deit_small.yaml
#
# ./tutorials:
# cifar10.ipynb  coco_caption_training.ipynb
#
# ./vision_lstm:
# __init__.py	 vision_lstm.py       vision_transformer.py
# vision_lstm2.py  vision_lstm_util.py

# %%
# !pip install -q einops transformers

# %%
# !pip install -q kappamodules kappautils kappaschedules kappaconfig kappadata kappaprofiler
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.7/77.7 kB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.5/144.5 kB 10.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 107.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 80.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 50.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 7.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 86.0 MB/s eta 0:00:00

# %%
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
secret_value_0 = user_secrets.get_secret("hf")

# %%
# General imports
import torch
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import transforms
from tqdm.auto import tqdm
import matplotlib.pyplot as plt

# %%
# Initialize device
if torch.cuda.is_available():
    device = torch.device("cuda")
    print(f"GPU: {torch.cuda.get_device_name()}")
else:
    device = torch.device("cpu")
print(f"Device: {device}")
# Out:
# GPU: Tesla P100-PCIE-16GB
# Device: cuda

# %%
# Point Python to the repo's src/ so 'ksuit' and 'vislstm' are top-level packages
import sys, os

REPO_ROOT = "/kaggle/working/caption-lstm"  # adjust if your cwd differs
SRC_DIR = os.path.join(REPO_ROOT, "src")
if SRC_DIR not in sys.path:
    sys.path.insert(0, SRC_DIR)

print("Added to sys.path:", SRC_DIR)
# Out:
# Added to sys.path: /kaggle/working/caption-lstm/src

# %%
# Import dataset and collator
from ksuit.datasets.coco_captions_dataset import CocoCaptionsDataset
from ksuit.data.collators.caption_collator import CaptionCollator

# Image transforms (resize to 224x224 for ViL)
image_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# Create datasets
train_dataset = CocoCaptionsDataset(
    root="/kaggle/input/coco-2017-dataset/coco2017",
    split="train",
    return_all_captions=False,  # Random caption per image
)

val_dataset = CocoCaptionsDataset(
    root="/kaggle/input/coco-2017-dataset/coco2017",
    split="val",
    return_all_captions=True,  # All captions for evaluation
)

print(f"Train dataset: {len(train_dataset)} images")
print(f"Val dataset: {len(val_dataset)} images")
# Out:
# Train dataset: 118287 images
# Val dataset: 5000 images

# %%
# Create collator and dataloaders
collator = CaptionCollator(transform=image_transform)

batch_size = 8
train_dataloader = DataLoader(
    train_dataset,
    batch_size=batch_size,
    shuffle=True,
    collate_fn=collator,
    num_workers=2,
    drop_last=True,
)

val_dataloader = DataLoader(
    val_dataset,
    batch_size=batch_size,
    shuffle=False,
    collate_fn=collator,
    num_workers=2,
)

print(f"Train batches: {len(train_dataloader)}")
print(f"Val batches: {len(val_dataloader)}")
# Out:
# Train batches: 14785
# Val batches: 625

# %%
# Download the updated model.py with fixed pooling support
# !wget -q https://raw.githubusercontent.com/omar-A-hassan/caption-lstm/main/caption_lstm/model.py \
      -O /kaggle/working/caption-lstm/caption_lstm/model.py

print("Updated model.py")
# Out:
# Updated model.py

# %%
# Reload the model module to get the updated code
import sys
import importlib

# Clear cached modules
if 'caption_lstm.model' in sys.modules:
    del sys.modules['caption_lstm.model']
if 'caption_lstm' in sys.modules:
    del sys.modules['caption_lstm']

# Re-import
from caption_lstm.model import ViLCap, ViLCapConfig

print("Reloaded model module with updated pooling support")
# Out:
# 2025-10-11 22:56:14.950181: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1760223375.134811      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1760223375.190734      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Reloaded model module with updated pooling support

# %%
# Import model
from caption_lstm.model import ViLCap, ViLCapConfig

# Create config
config = ViLCapConfig(
    # Encoder (ViL-T configuration)
    encoder_dim=192,
    encoder_depth=24,
    encoder_input_shape=(3, 224, 224),
    encoder_patch_size=16,
    encoder_pooling="bilateral_avg",
    encoder_drop_path_rate=0.0,
    encoder_pretrained_path="/kaggle/input/vil-encoder/vil2_tiny16_e400_in1k.th",  # Set to path if using pretrained encoder
    
    # Decoder
    decoder_dim=512,
    decoder_num_blocks=3,
    decoder_num_heads=4,
    decoder_dropout=0.2,
    max_caption_length=50,
    
    # Tokenizer
    tokenizer_model="bert-base-uncased",
)

# Create model
model = ViLCap(config).to(device)
print(f"Total parameters: {sum(p.numel() for p in model.parameters()) / 1e6:.1f}M")
print(f"Encoder parameters: {sum(p.numel() for p in model.encoder.parameters()) / 1e6:.1f}M")
print(f"Decoder parameters: {sum(p.numel() for p in model.decoder.parameters()) / 1e6:.1f}M")
# Out:
# /kaggle/working/caption-lstm/vision_lstm/vision_lstm.py:524: UserWarning: You are using an old version of VisionLSTM that uses (i) bilateral_avg pooling instead of bilateral_concat (ii) causal conv1d instead of conv2d before q and k (iii) no biases in projection and layernorms. These three changes improve ImageNet-1K accuracy of a ViL-T from 77.3% to 78.1%. We recommend to use VisionLSTM2 instead of VisionLSTM.
#   warnings.warn(
# Loaded encoder weights from /kaggle/input/vil-encoder/vil2_tiny16_e400_in1k.th
# mLSTMLayerConfig(proj_factor=2.0, round_proj_up_dim_up=True, round_proj_up_to_multiple_of=64, _proj_up_dim=1024, conv1d_kernel_size=4, qkv_proj_blocksize=4, num_heads=4, bidirectional=False, quaddirectional=False, sharedirs=False, alternation=None, layerscale=None, use_conv2d=False, use_v_conv=False, share_conv=True, embedding_dim=512, bias=False, dropout=0.0, context_length=50, _num_blocks=3, _inner_embedding_dim=1024)
# mLSTMLayerConfig(proj_factor=2.0, round_proj_up_dim_up=True, round_proj_up_to_multiple_of=64, _proj_up_dim=1024, conv1d_kernel_size=4, qkv_proj_blocksize=4, num_heads=4, bidirectional=False, quaddirectional=False, sharedirs=False, alternation=None, layerscale=None, use_conv2d=False, use_v_conv=False, share_conv=True, embedding_dim=512, bias=False, dropout=0.0, context_length=50, _num_blocks=3, _inner_embedding_dim=1024)
# mLSTMLayerConfig(proj_factor=2.0, round_proj_up_dim_up=True, round_proj_up_to_multiple_of=64, _proj_up_dim=1024, conv1d_kernel_size=4, qkv_proj_blocksize=4, num_heads=4, bidirectional=False, quaddirectional=False, sharedirs=False, alternation=None, layerscale=None, use_conv2d=False, use_v_conv=False, share_conv=True, embedding_dim=512, bias=False, dropout=0.0, context_length=50, _num_blocks=3, _inner_embedding_dim=1024)
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Loading pretrained BERT embeddings...
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
#   BERT embedding dim: 768
#   Decoder embedding dim: 512
#   Vocab size: 30523
#   Using projection: 768 -> 512
#   ✓ Projected and copied 30522 embeddings
#   ✓ 1 new tokens keep random initialization
# ✓ Pretrained embeddings initialized successfully!
# Total parameters: 42.2M
# Encoder parameters: 5.9M
# Decoder parameters: 36.2M

# %%
# Hyperparameters
epochs = 5
lr = 1e-4
weight_decay = 0.01

# Optimizer and scheduler
optimizer = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)

total_updates = len(train_dataloader) * epochs
warmup_updates = int(total_updates * 0.1)

# Learning rate schedule (linear warmup + linear decay)
lrs = torch.cat([
    torch.linspace(0, lr, warmup_updates),
    torch.linspace(lr, 0, total_updates - warmup_updates),
])

print(f"Total updates: {total_updates}")
print(f"Warmup updates: {warmup_updates}")
# Out:
# Total updates: 73925
# Warmup updates: 7392

# %%
# Training loop
update = 0
train_losses = []
val_losses = []

pbar = tqdm(total=total_updates)
pbar.set_description("train_loss: ????? val_loss: ?????")

for epoch in range(epochs):
    # Training
    model.train()
    epoch_loss = 0
    
    for batch in train_dataloader:
        images = batch['images'].to(device)
        captions = batch['captions']
        
        # Schedule learning rate
        for param_group in optimizer.param_groups:
            param_group['lr'] = lrs[update]
        
        # Forward pass
        output = model(images, captions=captions, mode='train')
        logits = output['logits']
        target_ids = output['target_ids']
        attention_mask = output['attention_mask']
        
        # Compute loss (cross entropy)
        # Flatten for loss computation
        logits_flat = logits.reshape(-1, logits.size(-1))
        target_flat = target_ids.reshape(-1)
        
        # Compute loss only on non-padded tokens
        mask_flat = attention_mask.reshape(-1)
        loss = F.cross_entropy(logits_flat, target_flat, reduction='none')
        loss = (loss * mask_flat).sum() / mask_flat.sum()
        
        # Backward pass
        loss.backward()
        
        # Gradient clipping
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        
        # Update
        optimizer.step()
        optimizer.zero_grad()
        
        # Logging
        train_losses.append(loss.item())
        epoch_loss += loss.item()
        update += 1
        
        pbar.update(1)
        pbar.set_description(f"train_loss: {loss.item():.4f}")
    
    # Validation
    model.eval()
    val_loss = 0
    num_val_batches = 0
    
    with torch.no_grad():
        for batch in val_dataloader:
            images = batch['images'].to(device)
            # For validation, take first caption from each image's caption list
            captions = [caps[0] if isinstance(caps, list) else caps for caps in batch['captions']]
            
            output = model(images, captions=captions, mode='train')
            logits = output['logits']
            target_ids = output['target_ids']
            attention_mask = output['attention_mask']
            
            logits_flat = logits.reshape(-1, logits.size(-1))
            target_flat = target_ids.reshape(-1)
            mask_flat = attention_mask.reshape(-1)
            
            loss = F.cross_entropy(logits_flat, target_flat, reduction='none')
            loss = (loss * mask_flat).sum() / mask_flat.sum()
            
            val_loss += loss.item()
            num_val_batches += 1
            
            # Limit validation batches for speed
            if num_val_batches >= 100:
                break
    
    val_loss /= num_val_batches
    val_losses.append(val_loss)
    
    print(f"\nEpoch {epoch+1}/{epochs} - Train Loss: {epoch_loss/len(train_dataloader):.4f}, Val Loss: {val_loss:.4f}")

pbar.close()
# Out:
#   0%|          | 0/73925 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/transformers/tokenization_utils_base.py in convert_to_tensors(self, tensor_type, prepend_batch_axis)
#     777                 if not is_tensor(value):
# --> 778                     tensor = as_tensor(value)
#     779
#
# /usr/local/lib/python3.11/dist-packages/transformers/tokenization_utils_base.py in as_tensor(value, dtype)
#     739                     return torch.from_numpy(np.array(value))
# --> 740                 return torch.tensor(value)
#     741
#
# ValueError: expected sequence of length 10 at dim 1 (got 9)
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_19/790131967.py in <cell line: 0>()
#      21
#      22         # Forward pass
# ---> 23         output = model(images, captions=captions, mode='train')
#      24         logits = output['logits']
#      25         target_ids = output['target_ids']
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /kaggle/working/caption-lstm/caption_lstm/model.py in forward(self, images, captions, mode)
#     262
#     263             # Prepare teacher forcing inputs
# --> 264             tokenized = self.tokenizer.prepare_teacher_forcing_inputs(
#     265                 captions,
#     266                 device=images.device
#
# /kaggle/working/caption-lstm/caption_lstm/tokenizer.py in prepare_teacher_forcing_inputs(self, captions, device)
#     115         """
#     116         # Encode captions
# --> 117         encoded = self.encode(captions, device=device)
#     118         input_ids = encoded['input_ids']
#     119
#
# /kaggle/working/caption-lstm/caption_lstm/tokenizer.py in encode(self, captions, device)
#      46         """
#      47         # Encode captions first WITHOUT special tokens
# ---> 48         encoded = self.tokenizer(
#      49             captions,
#      50             padding=False,  # Don't pad yet
#
# /usr/local/lib/python3.11/dist-packages/transformers/tokenization_utils_base.py in __call__(self, text, text_pair, text_target, text_pair_target, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, padding_side, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    2865             if not self._in_target_context_manager:
#    2866                 self._switch_to_input_mode()
# -> 2867             encodings = self._call_one(text=text, text_pair=text_pair, **all_kwargs)
#    2868         if text_target is not None:
#    2869             self._switch_to_target_mode()
#
# /usr/local/lib/python3.11/dist-packages/transformers/tokenization_utils_base.py in _call_one(self, text, text_pair, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, padding_side, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, split_special_tokens, **kwargs)
#    2953                 )
#    2954             batch_text_or_text_pairs = list(zip(text, text_pair)) if text_pair is not None else text
# -> 2955             return self.batch_encode_plus(
#    2956                 batch_text_or_text_pairs=batch_text_or_text_pairs,
#    2957                 add_special_tokens=add_special_tokens,
#
# /usr/local/lib/python3.11/dist-packages/transformers/tokenization_utils_base.py in batch_encode_plus(self, batch_text_or_text_pairs, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, padding_side, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, split_special_tokens, **kwargs)
#    3154         )
#    3155
# -> 3156         return self._batch_encode_plus(
#    3157             batch_text_or_text_pairs=batch_text_or_text_pairs,
#    3158             add_special_tokens=add_special_tokens,
#
# /usr/local/lib/python3.11/dist-packages/transformers/tokenization_utils_fast.py in _batch_encode_plus(self, batch_text_or_text_pairs, add_special_tokens, padding_strategy, truncation_strategy, max_length, stride, is_split_into_words, pad_to_multiple_of, padding_side, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, split_special_tokens)
#     587         for input_ids in sanitized_tokens["input_ids"]:
#     588             self._eventual_warn_about_too_long_sequence(input_ids, max_length, verbose)
# --> 589         return BatchEncoding(sanitized_tokens, sanitized_encodings, tensor_type=return_tensors)
#     590
#     591     def _encode_plus(
#
# /usr/local/lib/python3.11/dist-packages/transformers/tokenization_utils_base.py in __init__(self, data, encoding, tensor_type, prepend_batch_axis, n_sequences)
#     240         self._n_sequences = n_sequences
#     241
# --> 242         self.convert_to_tensors(tensor_type=tensor_type, prepend_batch_axis=prepend_batch_axis)
#     243
#     244     @property
#
# /usr/local/lib/python3.11/dist-packages/transformers/tokenization_utils_base.py in convert_to_tensors(self, tensor_type, prepend_batch_axis)
#     792                         "Please see if a fast version of this tokenizer is available to have this feature available."
#     793                     ) from e
# --> 794                 raise ValueError(
#     795                     "Unable to create tensor, you should probably activate truncation and/or padding with"
#     796                     " 'padding=True' 'truncation=True' to have batched tensors with the same length. Perhaps your"
#
# ValueError: Unable to create tensor, you should probably activate truncation and/or padding with 'padding=True' 'truncation=True' to have batched tensors with the same length. Perhaps your features (`input_ids` in this case) have excessive nesting (inputs type `list` where type `int` is expected).

# %%
# Plot training curves
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

axes[0].plot(range(len(train_losses)), train_losses)
axes[0].set_xlabel('Updates')
axes[0].set_ylabel('Train Loss')
axes[0].set_title('Training Loss')
axes[0].grid(True)

axes[1].plot(range(len(val_losses)), val_losses, marker='o')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Val Loss')
axes[1].set_title('Validation Loss')
axes[1].grid(True)

plt.tight_layout()
plt.show()

# %%
# Generate captions for sample images
model.eval()

# Get a batch from validation set
sample_batch = next(iter(val_dataloader))
sample_images = sample_batch['images'][:8].to(device)
sample_gt_captions = sample_batch['captions'][:8]

# Generate captions
with torch.no_grad():
    generated_captions = model.generate_captions(sample_images, temperature=1.0)

# Display results
fig, axes = plt.subplots(2, 4, figsize=(20, 10))
axes = axes.flatten()

# Unnormalize images for display
mean = torch.tensor([0.485, 0.456, 0.406]).view(3, 1, 1)
std = torch.tensor([0.229, 0.224, 0.225]).view(3, 1, 1)
sample_images_display = sample_images.cpu() * std + mean

for i in range(8):
    axes[i].imshow(sample_images_display[i].permute(1, 2, 0).clip(0, 1))
    axes[i].axis('off')
    
    # Get ground truth (first caption if list)
    gt = sample_gt_captions[i][0] if isinstance(sample_gt_captions[i], list) else sample_gt_captions[i]
    
    axes[i].set_title(f"Generated: {generated_captions[i]}\n\nGT: {gt}", fontsize=8, wrap=True)

plt.tight_layout()
plt.show()

# %%
# Download the updated mbr_decoder.py
# !wget -q https://raw.githubusercontent.com/omar-A-hassan/caption-lstm/main/caption_lstm/mbr_decoder.py \
      -O /kaggle/working/caption-lstm/caption_lstm/mbr_decoder.py

print("Updated mbr_decoder.py")

# %%
# Reload the mbr_decoder module to get the updated code
import importlib
import caption_lstm.mbr_decoder
importlib.reload(caption_lstm.mbr_decoder)

print("Reloaded mbr_decoder module with updated code")

# %%
# MBR Decoding: Generate better captions using Minimum Bayes Risk
# First install mbrs library
# !pip install -q mbrs

from caption_lstm.mbr_decoder import MBRCaptionDecoder

# Initialize MBR decoder
print("Initializing MBR decoder with COMET metric...")
mbr_decoder = MBRCaptionDecoder(
    model=model,
    num_candidates=16,  # Generate 16 candidates per image
    metric_name="comet",
    metric_model="Unbabel/wmt22-comet-da",
    batch_size=64,
    fp16=True,
    temperature=1.0,
    top_k=50,
)

# Generate captions using MBR
print("Generating captions with MBR decoding (this may take a few minutes)...")
with torch.no_grad():
    mbr_captions = mbr_decoder.decode(sample_images)

# Display MBR results - one image per row (vertical layout)
fig, axes = plt.subplots(8, 1, figsize=(12, 40))  # 8 rows, 1 column

for i in range(8):
    axes[i].imshow(sample_images_display[i].permute(1, 2, 0).clip(0, 1))
    axes[i].axis('off')
    
    # Get ground truth (first caption if list)
    gt = sample_gt_captions[i][0] if isinstance(sample_gt_captions[i], list) else sample_gt_captions[i]
    
    axes[i].set_title(
        f"MBR: {mbr_captions[i]}\n\n"
        f"Simple: {generated_captions[i]}\n\n"
        f"GT: {gt}",
        fontsize=11,
        wrap=True,
        pad=20,
        loc='left'  # Left-align for readability
    )

# Add spacing between images
plt.subplots_adjust(hspace=0.4)
plt.tight_layout()
plt.show()

print("\nMBR Decoding complete!")
print("MBR generates multiple candidates and selects the best one based on COMET metric.")

# %%
# Save model checkpoint
torch.save({
    'epoch': epochs,
    'model_state_dict': model.state_dict(),
    'optimizer_state_dict': optimizer.state_dict(),
    'train_losses': train_losses,
    'val_losses': val_losses,
    'config': config,
}, 'vilcap_checkpoint.pth')

print("Model saved to vilcap_checkpoint.pth")
