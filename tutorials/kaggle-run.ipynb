# %% [markdown]
# # Diffusion-Only Kaggle Training Notebook
#
# This notebook is a clean diffusion pipeline for this repo: setup, smoke test, CC3M stage-1 training, and optional stage-2 COCO finetuning.

# %%
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
token = user_secrets.get_secret("GitHub")
secret_value_1 = user_secrets.get_secret("hf")

# %%
# !git clone https://github.com/omar-A-hassan/caption-lstm
# %cd /kaggle/working/caption-lstm
# Out:
# Cloning into 'caption-lstm'...
# remote: Enumerating objects: 1120, done.
# remote: Counting objects: 100% (1120/1120), done.
# remote: Compressing objects: 100% (601/601), done.
# remote: Total 1120 (delta 514), reused 1083 (delta 490), pack-reused 0 (from 0)
# Receiving objects: 100% (1120/1120), 43.92 MiB | 23.50 MiB/s, done.
# Resolving deltas: 100% (514/514), done.
# /kaggle/working/caption-lstm

# %%
# Diffusion training dependencies
# !pip install -q einops transformers kappamodules kappautils kappaschedules kappaconfig kappadata kappaprofiler tqdm pillow pandas
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.7/77.7 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.5/144.5 kB 7.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 89.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 75.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 55.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 33.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 14.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 77.9 MB/s eta 0:00:00

# %%
# Environment + import path setup
import os
import sys
from pathlib import Path

REPO_ROOT = Path('/kaggle/working/caption-lstm')
SRC_DIR = REPO_ROOT / 'src'
if str(REPO_ROOT) not in sys.path:
    sys.path.insert(0, str(REPO_ROOT))
if str(SRC_DIR) not in sys.path:
    sys.path.insert(0, str(SRC_DIR))

print('REPO_ROOT exists:', REPO_ROOT.exists())
print('SRC_DIR exists:', SRC_DIR.exists())
# Out:
# REPO_ROOT exists: True
# SRC_DIR exists: True

# %%
# Fixed dataset paths provided by you
CC3M_TRAIN_TSV = Path('/kaggle/input/datasets/tt0620/cc3m-large/cc3m_train.tsv')
CC3M_TRAIN_ROOT = Path('/kaggle/input/datasets/tt0620/cc3m-large/cc3m/training')
CC3M_VAL_TSV = Path('/kaggle/input/datasets/tt0620/cc3m-large/cc3m_val.tsv')
CC3M_VAL_ROOT = Path('/kaggle/input/datasets/tt0620/cc3m-large/cc3m/validation')
ENCODER_PATH = Path('/kaggle/input/vil-encoder/vil2_tiny16_e400_in1k.th')

for p in [CC3M_TRAIN_TSV, CC3M_TRAIN_ROOT, CC3M_VAL_TSV, CC3M_VAL_ROOT, ENCODER_PATH]:
    print(p, '->', p.exists())
# Out:
# /kaggle/input/datasets/tt0620/cc3m-large/cc3m_train.tsv -> True
# /kaggle/input/datasets/tt0620/cc3m-large/cc3m/training -> True
# /kaggle/input/datasets/tt0620/cc3m-large/cc3m_val.tsv -> True
# /kaggle/input/datasets/tt0620/cc3m-large/cc3m/validation -> True
# /kaggle/input/vil-encoder/vil2_tiny16_e400_in1k.th -> True

# %%
# Quick check that TSV format is image_path<TAB>caption
import csv

def preview_tsv(path, n=5):
    print('Preview:', path)
    with open(path, 'r', encoding='utf-8') as f:
        reader = csv.reader(f, delimiter='\t')
        for i, row in enumerate(reader):
            if i >= n:
                break
            print(f'row {i}: cols={len(row)}', row[:2])

preview_tsv(CC3M_TRAIN_TSV)
preview_tsv(CC3M_VAL_TSV)
# Out:
# Preview: /kaggle/input/datasets/tt0620/cc3m-large/cc3m_train.tsv
# row 0: cols=2 ['caption', 'image']
# row 1: cols=2 ['a very typical bus station', '0_2901536091.jpg']
# row 2: cols=2 ['sierra looked stunning in this top and this skirt while performing with person at their former university', '1_3239086386.jpg']
# row 3: cols=2 ['interior design of modern living room with fireplace in a new house', '3_3911723019.jpg']
# row 4: cols=2 ['cybernetic scene isolated on white background .', '4_2074769043.jpg']
# Preview: /kaggle/input/datasets/tt0620/cc3m-large/cc3m_val.tsv
# row 0: cols=2 ['caption', 'image']
# row 1: cols=2 ['author : a life in photography -- in pictures', '0_1595581236.jpg']
# row 2: cols=2 ['the - bedroom stone cottage can sleep people', '5_2227185927.jpg']
# row 3: cols=2 ['party in the park under cherry blossoms', '8_1666482269.jpg']
# row 4: cols=2 ["where 's the best place to show off your nails ? right in front of the castle , of course !", '11_3727110351.jpg']

# %%
# Stage 1: CC3M training (diffusion)
'!python tutorials/train_diffusion_vlm.py \
  --stage 1 \
  --data_root /kaggle/input/datasets/tt0620/cc3m-large/cc3m/training \
  --cc3m_tsv /kaggle/input/datasets/tt0620/cc3m-large/cc3m_train.tsv \
  --encoder_path /kaggle/input/vil-encoder/vil2_tiny16_e400_in1k.th \
  --output_dir /kaggle/working/checkpoints_diff_stage1 \
  --steps 50000 \
  --batch_size 32 \
  --grad_accum 32 \
  --num_workers 2 \
  --save_every 5000'
# Out:
# '!python tutorials/train_diffusion_vlm.py   --stage 1   --data_root /kaggle/input/datasets/tt0620/cc3m-large/cc3m/training   --cc3m_tsv /kaggle/input/datasets/tt0620/cc3m-large/cc3m_train.tsv   --encoder_path /kaggle/input/vil-encoder/vil2_tiny16_e400_in1k.th   --output_dir /kaggle/working/checkpoints_diff_stage1   --steps 50000   --batch_size 32   --grad_accum 32   --num_workers 2   --save_every 5000'

# %%
# Optional: Stage 2 COCO finetuning after Stage 1
# Update --resume if your latest checkpoint file differs.
# !python tutorials/train_diffusion_vlm.py \
  --stage 2 \
  --data_root /kaggle/input/coco-2017-dataset/coco2017 \
  --resume /kaggle/input/datasets/potatoguy44/s1zeft/final.pt \
  --encoder_path /kaggle/input/vil-encoder/vil2_tiny16_e400_in1k.th \
  --output_dir /kaggle/working/checkpoints_diff_stage2 \
  --steps 70000 \
  --batch_size 32 \
  --grad_accum 32 \
  --num_workers 2 \
  --save_every 2000 \
  --val_every 1000
# Out:
# 2026-04-13 12:43:14.279094: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776084194.482576      66 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776084194.544183      66 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Device: cuda
# Visible GPUs: 2
# ...
